# %% [markdown]
# <a href="https://colab.research.google.com/github/LewisLiu03/BooksManageSystem/blob/master/11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2024-06-01 07:41:36--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143808873 (137M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 137.15M   321MB/s    in 0.4s
#
# 2024-06-01 07:41:37 (321 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [143808873/143808873]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')

# %%
# !unzip /simplerecon.zip
# Out:
# Archive:  /simplerecon.zip
# 477aa5b32aa1b93f53abc72828f86023b6e46ce7
#    creating: simplerecon-main/
#   inflating: simplerecon-main/.gitignore
#   inflating: simplerecon-main/LICENSE
#   inflating: simplerecon-main/README.md
#    creating: simplerecon-main/configs/
#    creating: simplerecon-main/configs/data/
#   inflating: simplerecon-main/configs/data/7scenes_default.yaml
#   inflating: simplerecon-main/configs/data/7scenes_dense.yaml
#   inflating: simplerecon-main/configs/data/colmap_dense.yaml
#   inflating: simplerecon-main/configs/data/neucon_arkit_default.yaml
#   inflating: simplerecon-main/configs/data/neucon_arkit_dense.yaml
#   inflating: simplerecon-main/configs/data/scannet_default_test.yaml
#   inflating: simplerecon-main/configs/data/scannet_default_train.yaml
#   inflating: simplerecon-main/configs/data/scannet_default_val.yaml
#   inflating: simplerecon-main/configs/data/scannet_dense_test.yaml
#   inflating: simplerecon-main/configs/data/scannet_dense_val.yaml
# ...

# %%
# !conda env create -f ./simplerecon/simplerecon_env.yml
# Out:
# Channels:
#  - default
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
# ...
# pytorch-1.10.0       | 1.21 GB   | :   0% 0/1 [00:00<?, ?it/s]
# cudatoolkit-11.3.1   | 603.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2022.1.0         | 199.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# gcc_impl_linux-64-13 | 50.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# qt-main-5.15.8       | 50.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pillow-9.4.0         | 44.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libllvm15-15.0.7     | 31.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# python-3.9.7         | 27.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libdb-6.2.32         | 23.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# icu-70.1             | 13.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ...

# %%
# !conda env update -f ./simplerecon-main/simplerecon_env.yml
# Out:
# /bin/bash: line 1: conda: command not found
